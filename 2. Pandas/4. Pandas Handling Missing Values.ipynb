# %%
import pandas as pd

# %%
df = pd.read_csv("4. Missing Values CSV\Fortune_10.csv")
df
# Out:
#    ID             Name             Industry     Inception     No Values  \
# 0   1          Lamtone                  NaN  $11,757,018            NaN
# 1   2        Stripfind   Financial Services          2010  $12,329,371
# 2   3  Canecorporation            No Values           NaN  $10,597,009
# 3   4         Mattouch          IT Services          2013     No Values
# 4   5        Techdrill                  NaN          2009  $10,573,990
# 5   6         Techline               Health     No Values  $13,898,119
# 6   7          Cityace                  NaN          2010   $9,254,614
# 7   8   Kayelectronics               Health           NaN   $9,451,943
# 8   9          Ganzlax          IT Services          2011  $14,001,180
# 9  10      Trantraxlax  Government Services          2011  $11,088,336
#
#             Expenses        No Growth
# 0            5274553       NaN    30%
# 1    916,455 Dollars  11412916    NaN
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df = pd.read_csv("4. Missing Values CSV\Fortune_10.csv",na_values=["No Values","No"]) #To Consider a string as NaN
df
# Out:
#    ID             Name             Industry     Inception     No Values  \
# 0   1          Lamtone                  NaN  $11,757,018            NaN
# 1   2        Stripfind   Financial Services          2010  $12,329,371
# 2   3  Canecorporation                  NaN           NaN  $10,597,009
# 3   4         Mattouch          IT Services          2013           NaN
# 4   5        Techdrill                  NaN          2009  $10,573,990
# 5   6         Techline               Health           NaN  $13,898,119
# 6   7          Cityace                  NaN          2010   $9,254,614
# 7   8   Kayelectronics               Health           NaN   $9,451,943
# 8   9          Ganzlax          IT Services          2011  $14,001,180
# 9  10      Trantraxlax  Government Services          2011  $11,088,336
#
#             Expenses          No Growth
# 0            5274553         NaN    30%
# 1    916,455 Dollars  11412916.0    NaN
# 2  7,591,189 Dollars   3005820.0     7%
# ...

# %%
df = pd.read_csv("4. Missing Values CSV\Fortune_10.csv",na_values={"Industry":"No Values"}) #To Consider a string as NaN for particular column
df
# Out:
#    ID             Name             Industry     Inception     No Values  \
# 0   1          Lamtone                  NaN  $11,757,018            NaN
# 1   2        Stripfind   Financial Services          2010  $12,329,371
# 2   3  Canecorporation                  NaN           NaN  $10,597,009
# 3   4         Mattouch          IT Services          2013     No Values
# 4   5        Techdrill                  NaN          2009  $10,573,990
# 5   6         Techline               Health     No Values  $13,898,119
# 6   7          Cityace                  NaN          2010   $9,254,614
# 7   8   Kayelectronics               Health           NaN   $9,451,943
# 8   9          Ganzlax          IT Services          2011  $14,001,180
# 9  10      Trantraxlax  Government Services          2011  $11,088,336
#
#             Expenses        No Growth
# 0            5274553       NaN    30%
# 1    916,455 Dollars  11412916    NaN
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df = pd.read_csv("4. Missing Values CSV\Fortune_10.csv",keep_default_na=
False)
df
# Out:
#    ID             Name             Industry     Inception     No Values  \
# 0   1          Lamtone                       $11,757,018
# 1   2        Stripfind   Financial Services          2010  $12,329,371
# 2   3  Canecorporation            No Values                $10,597,009
# 3   4         Mattouch          IT Services          2013     No Values
# 4   5        Techdrill                   NA          2009  $10,573,990
# 5   6         Techline               Health     No Values  $13,898,119
# 6   7          Cityace                               2010   $9,254,614
# 7   8   Kayelectronics               Health                 $9,451,943
# 8   9          Ganzlax          IT Services          2011  $14,001,180
# 9  10      Trantraxlax  Government Services          2011  $11,088,336
#
#             Expenses        No Growth
# 0            5274553              30%
# 1    916,455 Dollars  11412916
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars        No   NULL
# ...

# %%
df = pd.read_csv("4. Missing Values CSV\Fortune_10.csv",na_filter=False) 
# To Check the value missing or not 
df
# Out:
#    ID             Name             Industry     Inception     No Values  \
# 0   1          Lamtone                       $11,757,018
# 1   2        Stripfind   Financial Services          2010  $12,329,371
# 2   3  Canecorporation            No Values                $10,597,009
# 3   4         Mattouch          IT Services          2013     No Values
# 4   5        Techdrill                   NA          2009  $10,573,990
# 5   6         Techline               Health     No Values  $13,898,119
# 6   7          Cityace                               2010   $9,254,614
# 7   8   Kayelectronics               Health                 $9,451,943
# 8   9          Ganzlax          IT Services          2011  $14,001,180
# 9  10      Trantraxlax  Government Services          2011  $11,088,336
#
#             Expenses        No Growth
# 0            5274553              30%
# 1    916,455 Dollars  11412916
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars        No   NULL
# ...
